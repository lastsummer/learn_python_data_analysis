# %%
import matplotlib
print(matplotlib.matplotlib_fname())
# Out:
# C:\Users\lasts\Anaconda2\envs\env_Python3.6\lib\site-packages\matplotlib\mpl-data\matplotlibrc

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

TSMC = pd.read_csv('2330stk.csv', sep='\t', index_col='Date')
TSMC.index = pd.to_datetime(TSMC.index) # 把index轉成datetime型態
close = TSMC.Close

fig = plt.figure()
plt.plot(close['2016'], '-')
plt.title('台積電 2016年收盤價曲線', loc='right')
# loc->title的位置
fig.savefig('day17_01.png')
# Out:
# C:\Users\lasts\Anaconda2\envs\env_Python3.6\lib\site-packages\matplotlib\font_manager.py:1328: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
